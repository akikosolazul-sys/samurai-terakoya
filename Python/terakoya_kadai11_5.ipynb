# %%
array = ["水","金","地","火","木","土","天","海","冥"]

for i in range(9):
  print(array[i])

i=0
while i < 9:
  print(array[i])
  i=i+1
# Out:
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
